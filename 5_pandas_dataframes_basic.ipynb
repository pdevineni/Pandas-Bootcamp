# %%
!#/usr/bin/python3

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import pandas as pd
import numpy as np 

pd.__version__
# Out:
# '1.4.2'

# %%
# Series vs Dataframes 
# Dataframes are two dimensional - indices and columns
# and dimensions are labeled
# Series are homogenous, but Dataframes can be heterogenous 
# Each dataframe column is a series 

# ndim -- number of dimensions 
# dtypes -- datatypes of dataframe columns
# shape - num rows and columns in dataframe  

# A dataframe can be represented using 
#   --- dict of tuples 
#   --- dict of dicts 
#   --- dict of series 
#   --- list of dicts

# %%
names = ['Olga', 'Andrew', 'Brian', 'Telulah', 'Nicole', 'Tilda']
ages = [22, 34, 42, 45, 65, 39]
married = [False, True, True, True, False, True]

# %%
# Pandas series
ser = pd.Series(names, name='name')

# Pandas Dataframe
df = pd.DataFrame({'name': names, 'age': ages, 'married': married})

# %%
df
# Out:
#       name  age  married
# 0     Olga   22    False
# 1   Andrew   34     True
# 2    Brian   42     True
# 3  Telulah   45     True
# 4   Nicole   65    False
# 5    Tilda   39     True

# %%
ser
# Out:
# 0       Olga
# 1     Andrew
# 2      Brian
# 3    Telulah
# 4     Nicole
# 5      Tilda
# Name: name, dtype: object

# %%
ser.iloc[2]

df.iloc[2,0]
# Out:
# 'Brian'
# 'Brian'

# %%
df.iloc[2]
# Out:
# name       Brian
# age           42
# married     True
# Name: 2, dtype: object

# %%
#  ndim - number of dimensions
ser.ndim
df.ndim
# Out:
# 1
# 2

# %%
ser.shape
df.shape
# Out:
# (6,)
# (6, 3)

# %%
ser 
df.name
# Out:
# 0       Olga
# 1     Andrew
# 2      Brian
# 3    Telulah
# 4     Nicole
# 5      Tilda
# Name: name, dtype: object
# 0       Olga
# 1     Andrew
# 2      Brian
# 3    Telulah
# 4     Nicole
# 5      Tilda
# Name: name, dtype: object

# %%
# Series are homogenous, dataframes are heterogenous

ser.dtype
df.dtypes # output is of type series
# Out:
# dtype('O')
# name       object
# age         int64
# married      bool
# dtype: object

# %%
# Creating a dataframe 

pd.DataFrame({'name':names, 'age': ages, 'married': married})

# All lists should be of the same length, 
# else results in an error
# Out:
#       name  age  married
# 0     Olga   22    False
# 1   Andrew   34     True
# 2    Brian   42     True
# 3  Telulah   45     True
# 4   Nicole   65    False
# 5    Tilda   39     True

# %%
# Method 1: Dict of tuples (column wise)

# (tuples are an immutable data structure)
tuple_names = tuple(names)
tuple_ages = tuple(ages)
tuple_married = tuple(married)

pd.DataFrame({'name': tuple_names, 'age': tuple_ages, 'married': tuple_married})


# Method 2: dict of series (column wise)

series_names = pd.Series(names)
series_ages = pd.Series(ages)
series_married = pd.Series(married)

pd.DataFrame({'name': series_names, 'age': series_ages, 'married': series_married})


# Method 3: dict of dicts (columnn wise)

dict_names = {k:v for k,v in enumerate(names)}
dict_ages = {k:v for k,v in enumerate(ages)}
dict_married = {k:v for k,v in enumerate(married)}

pd.DataFrame({'name': dict_names, 'age': dict_ages, 'married': dict_married})

# Method 4: list of dicts (row wise)

row_wise = [{'name': name, 'age': ages, 'married': married} for name, ages, married in zip(names, ages, married)]
pd.DataFrame(row_wise)
# Out:
#       name  age  married
# 0     Olga   22    False
# 1   Andrew   34     True
# 2    Brian   42     True
# 3  Telulah   45     True
# 4   Nicole   65    False
# 5    Tilda   39     True
#       name  age  married
# 0     Olga   22    False
# 1   Andrew   34     True
# 2    Brian   42     True
# 3  Telulah   45     True
# 4   Nicole   65    False
# 5    Tilda   39     True
#       name  age  married
# 0     Olga   22    False
# 1   Andrew   34     True
# 2    Brian   42     True
# 3  Telulah   45     True
# 4   Nicole   65    False
# 5    Tilda   39     True
#       name  age  married
# 0     Olga   22    False
# 1   Andrew   34     True
# 2    Brian   42     True
# 3  Telulah   45     True
# 4   Nicole   65    False
# 5    Tilda   39     True

# %%
df.info(verbose=True)

df.info(max_cols=2)

df.info(memory_usage=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     6 non-null      object
#  1   age      6 non-null      int64
#  2   married  6 non-null      bool
# dtypes: bool(1), int64(1), object(1)
# memory usage: 230.0+ bytes
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Columns: 3 entries, name to married
# dtypes: bool(1), int64(1), object(1)
# memory usage: 230.0+ bytes
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     6 non-null      object
#  1   age      6 non-null      int64
#  2   married  6 non-null      bool
# dtypes: bool(1), int64(1), object(1)
# memory usage: 230.0+ bytes

# %%
### Reading in Nutrition data 

import ssl
ssl._create_default_https_context = ssl._create_unverified_context

dataurl = 'https://andybek.com/pandas-nutrition'

nutrition = pd.read_csv(dataurl)
nutrition.head(10)
# Out:
#    Unnamed: 0                name serving_size  calories total_fat  \
# 0           0          Cornstarch        100 g       381      0.1g
# 1           1        Nuts, pecans        100 g       691       72g
# 2           2       Eggplant, raw        100 g        25      0.2g
# 3           3      Teff, uncooked        100 g       367      2.4g
# 4           4     Sherbet, orange        100 g       144        2g
# 5           5    Cauliflower, raw        100 g        25      0.3g
# 6           6    Taro leaves, raw        100 g        42      0.7g
# 7           7   Lamb, raw, ground        100 g       282       23g
# 8           8   Cheese, camembert        100 g       300       24g
# 9           9  Vegetarian fillets        100 g       290       18g
#
#   saturated_fat cholesterol     sodium  choline      folate  ...      fat  \
# 0           NaN           0    9.00 mg   0.4 mg    0.00 mcg  ...   0.05 g
# 1          6.2g           0    0.00 mg  40.5 mg   22.00 mcg  ...  71.97 g
# ...

# %%
nutrition.info(verbose=False, memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8789 entries, 0 to 8788
# Columns: 77 entries, Unnamed: 0 to water
# dtypes: int64(3), object(74)
# memory usage: 39.2 MB

# %%
# Data cleanup: Removing The Duplicated Index 
 
nutrition['Unnamed: 0']
# Out:
# 0          0
# 1          1
# 2          2
# 3          3
# 4          4
#         ...
# 8784    8784
# 8785    8785
# 8786    8786
# 8787    8787
# 8788    8788
# Name: Unnamed: 0, Length: 8789, dtype: int64

# %%
nutrition.drop('Unnamed: 0', axis=1)
# Out:
#                                                    name serving_size  \
# 0                                            Cornstarch        100 g
# 1                                          Nuts, pecans        100 g
# 2                                         Eggplant, raw        100 g
# 3                                        Teff, uncooked        100 g
# 4                                       Sherbet, orange        100 g
# ...                                                 ...          ...
# 8784  Beef, raw, all grades, trimmed to 0" fat, sepa...        100 g
# 8785  Lamb, cooked, separable lean only, composite o...        100 g
# 8786  Lamb, raw, separable lean and fat, composite o...        100 g
# 8787  Beef, raw, all grades, trimmed to 0" fat, sepa...        100 g
# 8788  Beef, raw, all grades, trimmed to 0" fat, sepa...        100 g
#
#       calories total_fat saturated_fat cholesterol    sodium  choline  \
# ...

# %%
nutrition.set_index('Unnamed: 0')
# Out:
#                                                          name serving_size  \
# Unnamed: 0
# 0                                                  Cornstarch        100 g
# 1                                                Nuts, pecans        100 g
# 2                                               Eggplant, raw        100 g
# 3                                              Teff, uncooked        100 g
# 4                                             Sherbet, orange        100 g
# ...                                                       ...          ...
# 8784        Beef, raw, all grades, trimmed to 0" fat, sepa...        100 g
# 8785        Lamb, cooked, separable lean only, composite o...        100 g
# 8786        Lamb, raw, separable lean and fat, composite o...        100 g
# 8787        Beef, raw, all grades, trimmed to 0" fat, sepa...        100 g
# 8788        Beef, raw, all grades, trimmed to 0" fat, sepa...        100 g
#
# ...

# %%
nutrition = pd.read_csv(dataurl, index_col=[0])
nutrition.head()
# Out:
#               name serving_size  calories total_fat saturated_fat cholesterol  \
# 0       Cornstarch        100 g       381      0.1g           NaN           0
# 1     Nuts, pecans        100 g       691       72g          6.2g           0
# 2    Eggplant, raw        100 g        25      0.2g           NaN           0
# 3   Teff, uncooked        100 g       367      2.4g          0.4g           0
# 4  Sherbet, orange        100 g       144        2g          1.2g         1mg
#
#      sodium  choline     folate folic_acid  ...      fat  \
# 0   9.00 mg   0.4 mg   0.00 mcg   0.00 mcg  ...   0.05 g
# 1   0.00 mg  40.5 mg  22.00 mcg   0.00 mcg  ...  71.97 g
# 2   2.00 mg   6.9 mg  22.00 mcg   0.00 mcg  ...   0.18 g
# 3  12.00 mg  13.1 mg          0          0  ...   2.38 g
# 4  46.00 mg   7.7 mg   4.00 mcg   0.00 mcg  ...   2.00 g
#
#   saturated_fatty_acids monounsaturated_fatty_acids  \
# 0               0.009 g                     0.016 g
# ...

# %%
# Gives a random row/sample everytime you call the function 
nutrition.sample(random_state=12)
# Out:
#                                                  name serving_size  calories  \
# 3713  Thuringer, pork, beef, summer sausage, cervelat        100 g       362
#
#      total_fat saturated_fat cholesterol      sodium  choline    folate  \
# 3713       30g           12g        74mg  1300.00 mg  78.9 mg  2.00 mcg
#
#      folic_acid  ...      fat saturated_fatty_acids  \
# 3713   0.00 mcg  ...  30.43 g              11.510 g
#
#      monounsaturated_fatty_acids polyunsaturated_fatty_acids  \
# 3713                    12.970 g                     1.200 g
#
#      fatty_acids_total_trans alcohol     ash caffeine theobromine    water
# 3713                74.00 mg   0.0 g  3.63 g  0.00 mg     0.00 mg  45.18 g
#
# [1 rows x 76 columns]

# %%
nutrition.sample(n=3)
# Out:
#                                                    name serving_size  \
# 5158  CARRABBA'S ITALIAN GRILL, spaghetti with pomod...        100 g
# 3404     Crustaceans, raw, mixed species, spiny lobster        100 g
# 1652                  Puddings, instant, dry mix, lemon        100 g
#
#       calories total_fat saturated_fat cholesterol      sodium choline  \
# 5158       104      1.8g          0.4g           0   218.00 mg  8.1 mg
# 3404       112      1.5g          0.2g        70mg   177.00 mg       0
# 1652       378      0.7g          0.1g           0  1332.00 mg       0
#
#          folate folic_acid  ...     fat saturated_fatty_acids  \
# 5158  32.00 mcg          0  ...  1.75 g               0.360 g
# 3404   1.00 mcg   0.00 mcg  ...  1.51 g               0.237 g
# 1652   0.00 mcg   0.00 mcg  ...  0.70 g               0.100 g
#
#      monounsaturated_fatty_acids polyunsaturated_fatty_acids  \
# 5158                     0.927 g                     0.375 g
# ...

# %%
# Sampling 1% of the values
nutrition.sample(frac=0.01)
# Out:
#                                                    name serving_size  \
# 338                                   TACO BELL, Nachos        100 g
# 8689  Beef, roasted, cooked, all grades, trimmed to ...        100 g
# 4003      Shortening, lard and vegetable oil, household        100 g
# 8705  Beef, grilled, cooked, select, trimmed to 1/8"...        100 g
# 2284             Braunschweiger (a liver sausage), pork        100 g
# ...                                                 ...          ...
# 8305  Beverages, vitamins B6 and B12, pantothenic ac...        100 g
# 4142  Soup, prepared with water, mix, dry, cream of ...        100 g
# 8065  Beef, broiled, cooked, choice, trimmed to 0" f...        100 g
# 3708    Beverages, Tropical Colada, V8 SPLASH Smoothies        100 g
# 7808  Shortening, soybean (partially hydrogenated)-c...        100 g
#
#       calories total_fat saturated_fat cholesterol     sodium   choline  \
# ...

# %%
# Sampling with Replacement or Weights

# With replacement
nutrition.sample(n=3, replace=True)
# Out:
#                                                    name serving_size  \
# 5705  Babyfood, junior, with applesauce and bananas,...        100 g
# 7734  Lamb, raw, separable lean only, shank off, chu...        100 g
# 1135                          Jerusalem-artichokes, raw        100 g
#
#       calories total_fat saturated_fat cholesterol    sodium  choline  \
# 5705        75      0.7g          0.1g           0   3.00 mg   4.1 mg
# 7734       121      4.1g          1.4g        64mg  60.00 mg        0
# 1135        73        0g           NaN           0   4.00 mg  30.0 mg
#
#          folate folic_acid  ...     fat saturated_fatty_acids  \
# 5705   4.00 mcg   0.00 mcg  ...  0.70 g               0.126 g
# 7734          0          0  ...  4.09 g               1.370 g
# 1135  13.00 mcg   0.00 mcg  ...  0.01 g               0.000 g
#
#      monounsaturated_fatty_acids polyunsaturated_fatty_acids  \
# 5705                     0.216 g                     0.253 g
# ...

# %%
# with Weights

weights = pd.Series(data=[10,10,10, 1, 2], index=[7,17,29, 5, 6])
weights

nutrition.sample(n=3, weights=weights)
# Out:
# 7     10
# 17    10
# 29    10
# 5      1
# 6      2
# dtype: int64
#                       name serving_size  calories total_fat saturated_fat  \
# 6         Taro leaves, raw        100 g        42      0.7g          0.2g
# 7        Lamb, raw, ground        100 g       282       23g           10g
# 29  Nuts, dried, pine nuts        100 g       673       68g          4.9g
#
#    cholesterol    sodium  choline      folate folic_acid  ...      fat  \
# 6            0   3.00 mg  12.8 mg  126.00 mcg   0.00 mcg  ...   0.74 g
# 7         73mg  59.00 mg  69.3 mg   18.00 mcg   0.00 mcg  ...  23.41 g
# 29           0   2.00 mg  55.8 mg   34.00 mcg   0.00 mcg  ...  68.37 g
#
#    saturated_fatty_acids monounsaturated_fatty_acids  \
# 6                0.151 g                     0.060 g
# 7               10.190 g                     9.600 g
# 29               4.899 g                    18.764 g
#
#    polyunsaturated_fatty_acids fatty_acids_total_trans alcohol     ash  \
# ...

# %%
# Dataframe Axes 

nutrition.head()

# Indices on each axes
nutrition.axes
# Out:
#               name serving_size  calories total_fat saturated_fat cholesterol  \
# 0       Cornstarch        100 g       381      0.1g           NaN           0
# 1     Nuts, pecans        100 g       691       72g          6.2g           0
# 2    Eggplant, raw        100 g        25      0.2g           NaN           0
# 3   Teff, uncooked        100 g       367      2.4g          0.4g           0
# 4  Sherbet, orange        100 g       144        2g          1.2g         1mg
#
#      sodium  choline     folate folic_acid  ...      fat  \
# 0   9.00 mg   0.4 mg   0.00 mcg   0.00 mcg  ...   0.05 g
# 1   0.00 mg  40.5 mg  22.00 mcg   0.00 mcg  ...  71.97 g
# 2   2.00 mg   6.9 mg  22.00 mcg   0.00 mcg  ...   0.18 g
# 3  12.00 mg  13.1 mg          0          0  ...   2.38 g
# 4  46.00 mg   7.7 mg   4.00 mcg   0.00 mcg  ...   2.00 g
#
#   saturated_fatty_acids monounsaturated_fatty_acids  \
# 0               0.009 g                     0.016 g
# ...

# %%
nutrition.axes[1][69]
# same as 
nutrition.columns[69]
# Out:
# 'polyunsaturated_fatty_acids'
# 'polyunsaturated_fatty_acids'

# %%
# the axis param

nutrition.dropna(axis=0)
# 0 => rows, 1 => columns
# Out:
#                                                    name serving_size  \
# 1                                          Nuts, pecans        100 g
# 3                                        Teff, uncooked        100 g
# 4                                       Sherbet, orange        100 g
# 5                                      Cauliflower, raw        100 g
# 6                                      Taro leaves, raw        100 g
# ...                                                 ...          ...
# 8784  Beef, raw, all grades, trimmed to 0" fat, sepa...        100 g
# 8785  Lamb, cooked, separable lean only, composite o...        100 g
# 8786  Lamb, raw, separable lean and fat, composite o...        100 g
# 8787  Beef, raw, all grades, trimmed to 0" fat, sepa...        100 g
# 8788  Beef, raw, all grades, trimmed to 0" fat, sepa...        100 g
#
#       calories total_fat saturated_fat cholesterol    sodium  choline  \
# ...

# %%
# Changing the index 

type(nutrition.index)

# RangeIndex - optimized version of index 
nutrition.indez = pd.RangeIndex(start=0, stop=8789, step=1)

type(nutrition.index)

nutrition.set_index('name')
# Out:
# pandas.core.indexes.numeric.Int64Index
# /var/folders/wr/xcz5m33x6c95ksqpy1nx49hh0000gn/T/ipykernel_11156/3054546626.py:6: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   nutrition.indez = pd.RangeIndex(start=0, stop=8789, step=1)
# pandas.core.indexes.numeric.Int64Index
#                                                    serving_size  calories  \
# name
# Cornstarch                                                100 g       381
# Nuts, pecans                                              100 g       691
# Eggplant, raw                                             100 g        25
# Teff, uncooked                                            100 g       367
# Sherbet, orange                                           100 g       144
# ...                                                         ...       ...
# ...
